# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import pandas as pd
import gc
import re
from qp_utils import (
    expand_vars, load_year, save_compact_meta,
    decode_labels, show_value_table_json, peek_sav_columns,
)

RAW_DIR = Path("Spss")
BASE_YEAR = 2010
years = list(range(2010, 2023+1))
files = {}
for y in years:
    p = RAW_DIR / f"QP_Trabalhadores_{y}.sav"
    if p.exists():
        files[y] = p

print()
def strip_year_tag_any(name: str) -> str:
    s = re.sub(r'_(\d{2})(?=(_|$))', '', name)
    s = re.sub(r'(?<=\D)(\d{2})$', '', s)
    return s
def base_vars_from_sav(path: Path) -> set[str]:
    cols = peek_sav_columns(path)["var"].tolist()
    return {strip_year_tag_any(v) for v in cols}

vars_by_year: dict[int, set[str]] = {}
for y, p in sorted(files.items()):
    s = base_vars_from_sav(p)
    vars_by_year[y] = s
    print(f"Year {y}: {len(s)} base variables in {p.name}")


def base_vars_from_sav(path: Path) -> set[str]:
    cols = peek_sav_columns(path)["var"].tolist()
    return {strip_year_tag_any(v) for v in cols}

def build_presence_table(files: dict[int, Path], base_year: int, diff_only: bool = True):
    if base_year not in files:
        raise ValueError(f"base_year {base_year} not in files")

    # Build sets of base variable names per year
    vars_by_year: dict[int, set[str]] = {y: base_vars_from_sav(p) for y, p in files.items()}

    # Union of all variable base-names, so we see extras not in base too
    all_vars = sorted(set().union(*vars_by_year.values()))

    # Build presence matrix
    years_sorted = [base_year] + sorted([y for y in files if y != base_year])
    data = {
        y: [v in vars_by_year[y] for v in all_vars]
        for y in years_sorted
    }
    presence = pd.DataFrame(data, index=all_vars)

    # Optionally filter to differences vs base column
    base_col = years_sorted[0]
    if diff_only:
        mask = (presence.T != presence[base_col]).any()
        presence = presence.loc[mask]

    return presence

presence_df = build_presence_table(files, BASE_YEAR, diff_only=True)

# See the raw boolean table (if you want)
presence_df.sort_index(key=lambda s: s.str.lower()).head(10)

# wanted_tpl = ["ano_{yy}","nuemp_{yy}","nuest_{yy}","ntrab_{yy}","sexo_{yy}","idade_{yy}_TB_COD","dtadm_{yy}"]

# df_2008, meta_2008 = load_year(2008, files[2008], cols=expand_vars(wanted_tpl, 2008))
# df_2009, meta_2009 = load_year(2009, files[2009], cols=expand_vars(wanted_tpl, 2009))

# save_compact_meta(meta_2008, 2008, df_2008)
# save_compact_meta(meta_2009, 2009, df_2009)

# df = pd.concat([df_2008, df_2009], ignore_index=True, copy=False)
# del df_2008, df_2009, meta_2008, meta_2009; gc.collect()

# # decode labels where available (e.g., sexo)
# decode_labels(df, "sexo")

# # quick table for 2009
# show_value_table_json(df, "sexo", 2009, sort_index=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Year 2010: 42 base variables in QP_Trabalhadores_2010.sav
# Year 2011: 42 base variables in QP_Trabalhadores_2011.sav
# Year 2012: 42 base variables in QP_Trabalhadores_2012.sav
# Year 2013: 42 base variables in QP_Trabalhadores_2013.sav
# Year 2014: 42 base variables in QP_Trabalhadores_2014.sav
# Year 2015: 42 base variables in QP_Trabalhadores_2015.sav
# Year 2016: 42 base variables in QP_Trabalhadores_2016.sav
# Year 2017: 42 base variables in QP_Trabalhadores_2017.sav
# Year 2018: 42 base variables in QP_Trabalhadores_2018.sav
# Year 2019: 42 base variables in QP_Trabalhadores_2019.sav
# Year 2020: 42 base variables in QP_Trabalhadores_2020.sav
# Year 2021: 42 base variables in QP_Trabalhadores_2021.sav
# Year 2022: 44 base variables in QP_Trabalhadores_2022.sav
# Year 2023: 44 base variables in QP_Trabalhadores_2023.sav
#                 2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# ANTIG          False  False  False  False  False  False  False  False  False
# antig           True   True   True   True   True   True   True   True   True
# APLIC_IRCT_RU  False  False  False  False  False  False  False  False  False
# aplic_irct_ru  False  False  False  False  False  False  False  False  False
# CTPRO          False  False  False  False  False  False  False  False  False
# ctpro           True   True   True   True   True   True   True   True   True
# CTREM          False  False  False  False  False  False  False  False  False
# ctrem           True   True   True   True   True   True   True   True   True
# DT_ADM         False  False  False  False  False  False  False  False  False
# dt_adm          True   True   True   True   True   True   True   True   True
#
#                 2019   2020   2021   2022   2023
# ANTIG          False  False  False  False   True
# antig           True   True   True   True  False
# APLIC_IRCT_RU  False  False  False  False   True
# aplic_irct_ru  False  False  False   True  False
# CTPRO          False  False  False  False   True
# ctpro           True   True   True   True  False
# CTREM          False  False  False  False   True
# ctrem           True   True   True   True  False
# DT_ADM         False  False  False  False   True
# dt_adm          True   True   True   True  False

# %%
presence_df[[2009, 2008]].head(40)

# %%
peek_sav_columns(files[2010])
# Out:
#               var                                              label  \
# 0             ANO                                  Ano de referência
# 1         NPC_FIC        Número de Identificação Ficticio da empresa
# 2           NUEMP  Número da empresa (ligação com a série QP até ...
# 3          EMP_ID               ID da empresa (ano 2010 e seguintes)
# 4           NUEST  Número do estabelecimento (ligação com a série...
# 5        ESTAB_ID       ID do estabelecimento (ano 2010 e seguintes)
# 6           ntrab                              Número do Trabalhador
# 7           nacio                                      Nacionalidade
# 8            sexo                                               Sexo
# 9       idade_Cod                                              Idade
# 10         dt_adm                         Data de admissão (mês ano)
# 11          antig                             Antiguidade na empresa
# 12        dt_prom                  Data da última promoção (mês ano)
# 13  IRCT_FICTICIO  Instrumento de Regulamentação Colectiva do Tra...
# 14     IRCT_LABEL                                         IRCT LABEL
# 15          ctpro                             Categoria profissional
# 16         sitpro                              Situação na profissão
# 17     tipo_contr                                   Tipo de contrato
# 18    tipo_contr1                         Tipo de contrato (nível 1)
# 19        reg_dur                      Regime de duração do trabalho
# 20         habil1                 Habilitações literárias (1 dígito)
# 21         habil2                Habilitações literárias (2 dígitos)
# 22          habil                            Habilitações literárias
# 23         nqual1                              Nível de qualificação
# 24        prof_4d  Classificação Portuguesa de Profissões (CPP 20...
# 25        prof_3d  Classificação Portuguesa de Profissões (CPP 20...
# 26        prof_2d  Classificação Portuguesa de Profissões (CPP 20...
# 27        prof_1d  Classificação Portuguesa de Profissões (CPP 20...
# 28          ctrem                            Controle de remuneração
# 29          rbase                      Remuneração base paga (euros)
# 30         rganho                          Remuneração ganho (euros)
# 31         rextra                    Remuneração suplementar (euros)
# 32      prest_reg                       Prestações regulares (euros)
# 33    prest_irreg                     Prestações irregulares (euros)
# 34   esc_rem_base                 Escalão de remuneração mensal base
# 35  esc_rem_ganho                Escalão de remuneração mensal ganho
# 36            pnt   Período normal de trabalho semanal (PNT) (horas)
# 37       hnormais        Horas mensais remuneradas - normais (horas)
# 38         hextra  Horas mensais remuneradas - suplementares (horas)
# 39    reminf_mot1                 Remuneração base<devida - motivo 1
# 40    reminf_mot2                 Remuneração base<devida - motivo 2
# 41    reminf_mot3                 Remuneração base<devida - motivo 3
#
#       spss_type
# 0     STRING(8)
# 1     STRING(8)
# 2     STRING(8)
# 3     STRING(8)
# 4     STRING(8)
# 5     STRING(8)
# 6     STRING(8)
# 7     STRING(8)
# 8     STRING(8)
# 9     STRING(8)
# 10    STRING(8)
# 11    STRING(8)
# 12    STRING(8)
# 13   STRING(24)
# 14  STRING(144)
# 15    STRING(8)
# 16    STRING(8)
# 17    STRING(8)
# 18    STRING(8)
# 19    STRING(8)
# 20    STRING(8)
# 21    STRING(8)
# 22    STRING(8)
# 23    STRING(8)
# 24    STRING(8)
# 25    STRING(8)
# 26    STRING(8)
# 27    STRING(8)
# 28    STRING(8)
# 29    STRING(8)
# 30    STRING(8)
# 31    STRING(8)
# 32    STRING(8)
# 33    STRING(8)
# 34    STRING(8)
# 35    STRING(8)
# 36    STRING(8)
# 37    STRING(8)
# 38    STRING(8)
# 39    STRING(8)
# 40    STRING(8)
# 41    STRING(8)

# %%
# Sort index by alphabetical order of variable base-names ignoring upper/lower case
presence_df.sort_index(key=lambda s: s.str.lower()).tail(40)
# Out:
#               2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# ntrab         True   True   True   True   True   True   True   True   True
# NTRAB        False  False  False  False  False  False  False  False  False
# pnt           True   True   True   True   True   True   True   True   True
# PNT          False  False  False  False  False  False  False  False  False
# prest_irreg   True   True   True   True   True   True   True   True   True
# PREST_IRREG  False  False  False  False  False  False  False  False  False
# prest_reg     True   True   True   True   True   True   True   True   True
# PREST_REG    False  False  False  False  False  False  False  False  False
# prof_1d       True   True   True   True   True   True   True   True   True
# PROF_1D      False  False  False  False  False  False  False  False  False
# prof_2d       True   True   True   True   True   True   True   True   True
# PROF_2D      False  False  False  False  False  False  False  False  False
# PROF_3D      False  False  False  False  False  False  False  False  False
# prof_3d       True   True   True   True   True   True   True   True   True
# prof_4d       True   True   True   True   True   True   True   True   True
# PROF_4D      False  False  False  False  False  False  False  False  False
# rbase         True   True   True   True   True   True   True   True   True
# RBASE        False  False  False  False  False  False  False  False  False
# reg_dur       True   True   True   True   True   True   True   True   True
# REG_DUR      False  False  False  False  False  False  False  False  False
# reg_reforma  False  False  False  False  False  False  False  False  False
# REG_REFORMA  False  False  False  False  False  False  False  False  False
# reminf_mot1   True   True   True   True   True   True   True   True   True
# REMINF_MOT1  False  False  False  False  False  False  False  False  False
# reminf_mot2   True   True   True   True   True   True   True   True   True
# REMINF_MOT2  False  False  False  False  False  False  False  False  False
# reminf_mot3   True   True   True   True   True   True   True   True   True
# REMINF_MOT3  False  False  False  False  False  False  False  False  False
# REXTRA       False  False  False  False  False  False  False  False  False
# rextra        True   True   True   True   True   True   True   True   True
# rganho        True   True   True   True   True   True   True   True   True
# RGANHO       False  False  False  False  False  False  False  False  False
# sexo          True   True   True   True   True   True   True   True   True
# SEXO         False  False  False  False  False  False  False  False  False
# sitpro        True   True   True   True   True   True   True   True   True
# SITPRO       False  False  False  False  False  False  False  False  False
# tipo_contr    True   True   True   True   True   True   True   True   True
# TIPO_CONTR   False  False  False  False  False  False  False  False  False
# TIPO_CONTR1  False  False  False  False  False  False  False  False  False
# tipo_contr1   True   True   True   True   True   True   True   True   True
#
#               2019   2020   2021   2022   2023
# ntrab         True   True   True   True  False
# NTRAB        False  False  False  False   True
# pnt           True   True   True   True  False
# PNT          False  False  False  False   True
# prest_irreg   True   True   True   True  False
# PREST_IRREG  False  False  False  False   True
# prest_reg     True   True   True   True  False
# PREST_REG    False  False  False  False   True
# prof_1d       True   True   True   True  False
# PROF_1D      False  False  False  False   True
# prof_2d       True   True   True   True  False
# PROF_2D      False  False  False  False   True
# PROF_3D      False  False  False  False   True
# prof_3d       True   True   True   True  False
# prof_4d       True   True   True   True  False
# PROF_4D      False  False  False  False   True
# rbase         True   True   True   True  False
# RBASE        False  False  False  False   True
# reg_dur       True   True   True   True  False
# REG_DUR      False  False  False  False   True
# reg_reforma  False  False  False   True  False
# REG_REFORMA  False  False  False  False   True
# reminf_mot1   True   True   True   True  False
# REMINF_MOT1  False  False  False  False   True
# reminf_mot2   True   True   True   True  False
# REMINF_MOT2  False  False  False  False   True
# reminf_mot3   True   True   True   True  False
# REMINF_MOT3  False  False  False  False   True
# REXTRA       False  False  False  False   True
# rextra        True   True   True   True  False
# rganho        True   True   True   True  False
# RGANHO       False  False  False  False   True
# sexo          True   True   True   True  False
# SEXO         False  False  False  False   True
# sitpro        True   True   True   True  False
# SITPRO       False  False  False  False   True
# tipo_contr    True   True   True   True  False
# TIPO_CONTR   False  False  False  False   True
# TIPO_CONTR1  False  False  False  False   True
# tipo_contr1   True   True   True   True  False
